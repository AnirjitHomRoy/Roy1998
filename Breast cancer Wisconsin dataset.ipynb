# %% [markdown]
# # Logistic Regression

# %% [markdown]
# ## Importing the libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Importing the dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Breast Cancer Wisconsin data set
dataset = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Breast Cancer new project/Final Folder/Dataset/breast_cancer.csv')

# %%
dataset.isnull().sum()
# Out:
# Sample code number             0
# Clump Thickness                0
# Uniformity of Cell Size        0
# Uniformity of Cell Shape       0
# Marginal Adhesion              0
# Single Epithelial Cell Size    0
# Bare Nuclei                    0
# Bland Chromatin                0
# Normal Nucleoli                0
# Mitoses                        0
# Class                          0
# dtype: int64

# %%
dataset.head()
# Out:
#    Sample code number  Clump Thickness  ...  Mitoses  Class
# 0             1000025                5  ...        1      2
# 1             1002945                5  ...        1      2
# 2             1015425                3  ...        1      2
# 3             1016277                6  ...        1      2
# 4             1017023                4  ...        1      2
#
# [5 rows x 11 columns]

# %%
X = dataset.iloc[:, 1:-1].values
y = dataset.iloc[:, -1].values
type(X), type(y)
# Out:
# (numpy.ndarray, numpy.ndarray)

# %%
X
# Out:
# array([[ 5,  1,  1, ...,  3,  1,  1],
#        [ 5,  4,  4, ...,  3,  2,  1],
#        [ 3,  1,  1, ...,  3,  1,  1],
#        ...,
#        [ 5, 10, 10, ...,  8, 10,  2],
#        [ 4,  8,  6, ..., 10,  6,  1],
#        [ 4,  8,  8, ..., 10,  4,  1]])

# %%
np.unique(y)
# Out:
# array([2, 4])

# %%
X_test.shape
# Out:
# (137, 9)

# %% [markdown]
# ## Splitting the dataset into the Training set and Test set

# %%
from sklearn.model_selection import train_test_split  # library - sklearn, module - model_selection, function - train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %% [markdown]
# ## Training the Logistic Regression model on the Training set

# %%
from sklearn.linear_model import LogisticRegression  # LogisticRegression is a class
classifier = LogisticRegression(random_state = 0)
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=0, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %% [markdown]
# ## Predicting the Test set results

# %%
y_pred = classifier.predict(X_test)

# %% [markdown]
# ## Making the Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score
cm = confusion_matrix(y_test, y_pred)
acc = accuracy_score(y_test, y_pred)

print(cm)
print(acc)
# Out:
# [[84  3]
#  [ 3 47]]
# 0.9562043795620438

# %% [markdown]
# ## Computing the accuracy with k-Fold Cross Validation

# %%
from sklearn.model_selection import cross_val_score

accuracies = cross_val_score(estimator = classifier, X = X_train, y = y_train, cv = 10)
type(accuracies)
# Out:
# numpy.ndarray

# %%
print("Accuracy: {:.2f}%".format(accuracies.mean()*100))
print("Standard Deviation: {:.2f}%".format(accuracies.std()*100))
# Out:
# Accuracy: 96.70%
# Standard Deviation: 1.97%
